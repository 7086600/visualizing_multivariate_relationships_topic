# %%
# importing necessary libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# load the dataset
health_data = pd.read_csv('Life Expectancy Data.csv', sep=',')

# %%
# setting options
pd.set_option('display.max_columns', None)

# %%
# inspecting and cleaning data
print(health_data.shape)

# Strip whitespace from column names
health_data.columns = health_data.columns.str.strip().str.replace(' ', '_', regex=True)

'''
# case 2: Strip whitespace from column names
health_data.rename(columns={
    'Life expectancy ': 'Life_expectancy',
    'Measles ': 'Measles',
    'BMI ': 'BMI',
    'under-five deaths ': 'under_five_deaths',
    'Diphtheria ': 'Diphtheria',
    ' thinness  1-19 yearsq': 'thinness_1_19_years',
    ' thinness 5-9 years': 'thinness_5_9_years'}, inplace=True)
'''
print(health_data.columns)
health_data.head(10)
# Out:
# (2938, 22)
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1-19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')
#        Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
# 5  Afghanistan  2010  Developing             58.8            279.0
# 6  Afghanistan  2009  Developing             58.6            281.0
# ...

# %% [markdown]
# ## Scatter plots with visual cues

# %%
# create simple scatter plot
plt.figure(figsize=(10, 5))
sns.scatterplot(data=health_data, x='Schooling', y='Life_expectancy')
plt.title('Scatter Plot of Schooling vs Life Expectancy')
plt.xlabel('Schooling (Years)')
plt.ylabel('Life Expectancy (Years)')
plt.show()

# %%
# creating scatter plot with a visual cue
plt.figure(figsize=(10, 5))
sns.scatterplot(data=health_data, x='Schooling', y='Life_expectancy', hue=health_data['Status'], palette='bright')
plt.title('Scatter Plot of Schooling vs Life Expectancy')
plt.xlabel('Schooling (Years)')
plt.ylabel('Life Expectancy (Years)')
plt.show()

# %%
# scatter plot with 4 variables
plt.figure(figsize=(10, 5))
sns.scatterplot(data=health_data, x='Schooling', y='Life_expectancy', hue=health_data['Status'], style=health_data['Year'], palette='bright')
plt.title('Scatter Plot of Schooling vs Life Expectancy')
plt.xlabel('Schooling (Years)')
plt.ylabel('Life Expectancy (Years)')
plt.show()
# it's possible to use size as a visual cue, but it is not recommended for scatter plots with more than 3 variables
